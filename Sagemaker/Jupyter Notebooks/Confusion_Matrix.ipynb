# %%
import boto3
import numpy as np
from sklearn.metrics import confusion_matrix

from sagemaker.predictor import Predictor
from sagemaker.session import Session

sagemaker_session = Session()

predictor = Predictor(
    endpoint_name="pest-classifier-release",
    sagemaker_session=sagemaker_session
)

def get_all_s3_objects(session, bucket):
    continuation_token = None
    objects = []
    while True:
        list_kwargs = dict(MaxKeys=1000, Bucket=bucket)
        if continuation_token:
            list_kwargs['ContinuationToken'] = continuation_token
        response = session.list_objects_v2(**list_kwargs)
        if 'Contents' in response:
            objects += (response['Contents'])
        if not response.get('IsTruncated'):  # At the end of the list?
            break
        continuation_token = response.get('NextContinuationToken')    
    
    return objects



# Get a list of all the S3 objects that contain the test data images' URIs
s3 = boto3.client('s3')
bucket_name = "flylite-model-testing-pictures" 
uris = get_all_s3_objects(s3, bucket_name);
print("Num of uris: " + str(len(uris)))
# Out:
# Num of uris: 274

# %%
print(uris[0])
# Out:
# {'Key': 'gbm/04074856-3AFC-4A7A-8EEE-3604FE1E430B_1_105_c.jpeg', 'LastModified': datetime.datetime(2023, 3, 20, 19, 41, 12, tzinfo=tzlocal()), 'ETag': '"c27b1ae841ce1969fc684e6a79ca4800"', 'Size': 223885, 'StorageClass': 'STANDARD'}

# %%
from ast import literal_eval
import os
from PIL import Image #Make sure to pip install Pillow
import io
import base64



def get_size_format(b, factor=1024, suffix="B"):
    """
    Scale bytes to its proper byte format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
        if b < factor:
            return f"{b:.2f}{unit}{suffix}"
        b /= factor
    return f"{b:.2f}Y{suffix}"

def compress_img(image_data, new_size_ratio=0.9, quality=90, width=None, height=None, to_jpg=True):
    # load the image to memory
    
    img = Image.open(io.BytesIO(image_data))
    # print the original image shape
    print("[*] Image shape:", img.size)
    # get the original image size in bytes
    image_size = len(image_data)
    # print the size before compression/resizing
    print("[*] Size before compression:", get_size_format(image_size))
    if new_size_ratio < 1.0:
        # if resizing ratio is below 1.0, then multiply width & height with this ratio to reduce image size
        img = img.resize((int(img.size[0] * new_size_ratio), int(img.size[1] * new_size_ratio)), Image.ANTIALIAS)
        # print new image shape
        print("[+] New Image shape:", img.size)
    elif width and height:
        # if width and height are set, resize with them instead
        img = img.resize((width, height), Image.ANTIALIAS)
        # print new image shape
        print("[+] New w/h Image shape:", img.size)
    # split the filename and extension
    filename, ext = os.path.splitext("test.jpg")
    # make new filename appending _compressed to the original file name
    #if to_jpg:
        # change the extension to JPEG
    #    new_filename = f"{filename}_compressed.jpg"
    #else:
        # retain the same extension of the original image
    #    new_filename = f"{filename}_compressed{ext}"
    #try:
        # save the image with the corresponding quality and optimize set to True
    #    img.save(new_filename, quality=quality, optimize=True)
    #except OSError:
        # convert the image to RGB mode first
    #    img = img.convert("RGB")
        # save the image with the corresponding quality and optimize set to True
    #    img.save(new_filename, quality=quality, optimize=True)
    #print("[+] New file saved:", new_filename)
    # get the new image size in bytes
    #new_image_size = os.path.getsize(new_filename)
    
    
    imgByteArr = io.BytesIO()
    # image.save expects a file-like as a argument
    img.save(imgByteArr, format='JPEG')
    # Turn the BytesIO object back into a bytes object
    imgByteArr = imgByteArr.getvalue()
    
    new_image_size = len(imgByteArr)
    # print the new size in a good format
    print("[+] Size after compression:", get_size_format(new_image_size))
    # calculate the saving bytes
    saving_diff = new_image_size - image_size
    # print the saving percentage
    #print(f"[+] Image size change: {saving_diff/image_size*100:.2f}% of the original image size.")
    print("Output type: " + str(type(img.tobytes())))
    
    img.close()
    
    return imgByteArr
    

classes = {}
for uri in uris:
    label = uri['Key'][0:(uri['Key'].find('/'))]
    if label not in classes.keys():
        classes[label] = {'TP': 0, 'FP': 0, 'FN': 0}
        print("Added label " + label)
        
for uri in uris:
    label = uri['Key'][0:(uri['Key'].find('/'))]
    
    s3_object = s3.get_object(Bucket=bucket_name, Key=uri['Key'])['Body'].read()
    #print(uri['Key'])
    #print(type(s3_object))
    
    print("Predicting image " + str(uri['Key']) + " with size " + get_size_format(len(s3_object)))
    while len(s3_object) > 4000000:
        print("Compressing...")
        s3_object = compress_img(s3_object, new_size_ratio=.9)
    
    result = predictor.predict(s3_object, {"ContentType": "application/x-image", "Accept": "application/json;verbose"})
    prediction = literal_eval(result.decode('utf-8'))['predicted_label']
    
    #print("Prediction: " + prediction)
    
    if prediction == label:
        classes[label]['TP'] += 1
    else:
        classes[prediction]['FP'] += 1
        classes[label]['FN'] += 1

print(classes)
# Out:
# Added label gbm
# Added label neither
# Added label slf
# Predicting image gbm/04074856-3AFC-4A7A-8EEE-3604FE1E430B_1_105_c.jpeg with size 218.64KB
# Predicting image gbm/0678498C-0AC9-45C4-A316-043D3B6CB1E2_1_105_c.jpeg with size 191.63KB
# Predicting image gbm/067B1DCB-68C1-4DC5-84C9-F512754ECB91_1_105_c.jpeg with size 224.74KB
# Predicting image gbm/0887148D-1DBB-4A15-8BCD-BC1EE166CF62_1_105_c.jpeg with size 184.77KB
# Predicting image gbm/08884276-D8A8-4389-8559-8AB057823E51_1_105_c.jpeg with size 204.27KB
# Predicting image gbm/0A28FE9C-0CF6-4546-8105-F49C167C3848_1_105_c.jpeg with size 244.19KB
# Predicting image gbm/0BADC8A7-085E-48D3-BB23-E5D8885394FE_1_105_c.jpeg with size 247.15KB
# Predicting image gbm/0F94C399-6F42-4DBF-A9BA-91AB218A5BF9_1_105_c.jpeg with size 233.56KB
# Predicting image gbm/12C37139-723B-4872-B133-28BC43C60061_1_105_c.jpeg with size 184.35KB
# Predicting image gbm/174B61DD-D545-4851-B348-FBAC4BAF853E_1_105_c.jpeg with size 179.00KB
# Predicting image gbm/19257DFE-CEBE-4205-BC43-8C0AC3DE4EA2_1_105_c.jpeg with size 218.89KB
B
# Compressing...
# [*] Image shape: (4032, 3024)
# [*] Size before compression: 5.68MB
# [+] New Image shape: (3628, 2721)
# [+] Size after compression: 716.02KB
# Output type: <class 'bytes'>
# Predicting image gbm/IMG_2603.jpg with size 5.39MB
# Compressing...
# [*] Image shape: (4032, 3024)
# [*] Size before compression: 5.39MB
# [+] New Image shape: (3628, 2721)
# [+] Size after compression: 846.44KB
# Output type: <class 'bytes'>
# Predicting image gbm/IMG_2616.jpg with size 6.02MB
# Compressing...
# [*] Image shape: (4032, 3024)
# [*] Size before compression: 6.02MB
# [+] New Image shape: (3628, 2721)
# [+] Size after compression: 777.29KB
# Output type: <class 'bytes'>
# Predicting image gbm/IMG_2617.JPG with size 3.07MB
# Predicting image gbm/IMG_2618.JPG with size 2.98MB
# Predicting image gbm/IMG_2624.jpg with size 5.32MB
# Compressing...
# [*] Image shape: (4032, 3024)
# [*] Size before compression: 5.32MB
# [+] New Image shape: (3628, 2721)
# [+] Size after compression: 674.03KB
# Output type: <class 'bytes'>
# Predicting image neither/0.jpg with size 63.10KB
# Predicting image neither/10.jpg with size 186.33KB
# Predicting image neither/100.jpg with size 11.12KB
# Predicting image neither/1000.jpg with size 10.96KB
# Predicting image neither/1001.jpg with size 179.96KB
# Predicting image neither/1002.jpg with size 46.00KB
# Predicting image neither/1003.jpg with size 298.80KB
# Predicting image neither/1005.jpg with size 49.93KB
# Predicting image neither/1006.jpg with size 21.60KB
# Predicting image neither/1007.jpg with size 26.01KB
# Predicting image neither/1008.jpg with size 13.16KB
# Predicting image neither/1009.jpg with size 8.03KB
# Predicting image neither/101.jpg with size 13.16KB
# Predicting image neither/1010.jpg with size 30.94KB
# Predicting image neither/1011.jpg with size 7.50KB
# Predicting image neither/1012.jpg with size 9.88KB
# Predicting image neither/1013.jpg with size 10.15KB
# Predicting image neither/1015.jpg with size 12.52KB
# Predicting image neither/1016.jpg with size 8.54KB
# Predicting image neither/1017.jpg with size 12.67KB
# Predicting image neither/1018.jpg with size 5.90KB
# Predicting image neither/1019.jpg with size 96.03KB
# Predicting image neither/102.jpg with size 8.42KB
# Predicting image neither/1020.jpg with size 6.54KB
# Predicting image neither/1021.jpg with size 9.96KB
# Predicting image neither/1022.jpg with size 176.55KB
# Predicting image neither/1023.jpg with size 38.11KB
# Predicting image neither/1024.jpg with size 8.36KB
# Predicting image neither/1025.jpg with size 204.88KB
# Predicting image neither/1026.jpg with size 20.75KB
# Predicting image neither/1027.jpg with size 20.08KB
# Predicting image neither/1028.jpg with size 14.97KB
# Predicting image neither/103.jpg with size 81.47KB
# Predicting image neither/1030.jpg with size 15.90KB
# Predicting image neither/1031.jpg with size 11.11KB
# Predicting image neither/1032.jpg with size 18.20KB
# Predicting image neither/1033.jpg with size 14.16KB
# Predicting image neither/1034.jpg with size 14.26KB
# Predicting image neither/1035.jpg with size 15.66KB
# Predicting image neither/1036.jpg with size 15.94KB
# Predicting image neither/IMG_3070.jpeg with size 5.69MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.69MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 892.02KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3071.jpeg with size 5.49MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.49MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 774.69KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3072.jpeg with size 5.56MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.56MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 800.34KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3073.jpeg with size 5.55MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.55MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 885.48KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3074.jpeg with size 5.65MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.65MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 978.81KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3075.jpeg with size 6.05MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 6.05MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 1.01MB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3076.jpeg with size 5.56MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.56MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 901.21KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3077.jpeg with size 5.52MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5.52MB
# [+] New Image shape: (2721, 3628)
# [+] Size after compression: 840.86KB
# Output type: <class 'bytes'>
# Predicting image neither/IMG_3079.jpeg with size 5.69MB
# Compressing...
# [*] Image shape: (3024, 4032)
# [*] Size before compression: 5
# Predicting image neither/IMG_7248.jpeg with size 1.97MB
# Predicting image neither/IMG_7249.jpeg with size 1.84MB
# Predicting image neither/IMG_7250.jpeg with size 1.94MB
# Predicting image neither/IMG_7251.jpeg with size 1.79MB
# Predicting image neither/IMG_7252.jpeg with size 1.94MB
# Predicting image neither/IMG_7253.jpeg with size 1.93MB
# Predicting image neither/IMG_7254.jpeg with size 2.02MB
# Predicting image neither/IMG_7255.jpeg with size 1.82MB
# Predicting image neither/IMG_7256.jpeg with size 1.90MB
# Predicting image neither/IMG_7257.jpeg with size 1.86MB
# Predicting image neither/IMG_7258.jpeg with size 1.80MB
# Predicting image neither/IMG_7259.jpeg with size 1.87MB
# Predicting image neither/IMG_7260.jpeg with size 1.91MB
# Predicting image neither/IMG_7261.jpeg with size 2.03MB
# Predicting image neither/IMG_7262.jpeg with size 1.72MB
# Predicting image neither/IMG_7263.jpeg with size 1.96MB
# Predicting image neither/IMG_7264.jpeg with size 1.94MB
# Predicting image neither/IMG_7265.jpeg with size 2.01MB
# Predicting image neither/IMG_7266.jpeg with size 2.29MB
# Predicting image neither/IMG_7267.jpeg with size 1.91MB
# Predicting image neither/IMG_7268.jpeg with size 2.10MB
# Predicting image neither/IMG_7269.jpeg with size 2.10MB
# Predicting image neither/IMG_7270.jpeg with size 2.06MB
# Predicting image neither/IMG_7271.jpeg with size 2.09MB
# Predicting image neither/IMG_7272.jpeg with size 1.90MB
# Predicting image neither/IMG_7273.jpeg with size 2.07MB
# Predicting image neither/IMG_7274.jpeg with size 2.18MB
# Predicting image neither/IMG_7275.jpeg with size 1.94MB
# Predicting image neither/IMG_7276.jpeg with size 2.19MB
# Predicting image neither/IMG_7277.jpeg with size 2.10MB
# Predicting image neither/IMG_7278.jpeg with size 2.32MB
# Predicting image neither/IMG_7279.jpeg with size 2.13MB
# Predicting image neither/IMG_7280.jpeg with size 1.94MB
# Predicting image neither/IMG_7281.jpeg with size 2.09MB
# Predicting image neither/IMG_7282.jpeg with size 2.09MB
# Predicting image neither/IMG_7283.jpeg with size 2.00MB
# Predicting image neither/IMG_7284.jpeg with size 1.84MB
# Predicting image neither/IMG_7286.jpeg with size 2.11MB
# Predicting image neither/IMG_7287.jpeg with size 1.87MB
# Predicting image slf/1000.jpg with size 33.70KB
# Predicting image slf/1009.jpg with size 86.83KB
# Predicting image slf/1033.jpg with size 25.79KB
# Predicting image slf/1034.jpg with size 11.15KB
# Predicting image slf/1036.jpg with size 318.63KB
# Predicting image slf/1044.jpg with size 108.06KB
# Predicting image slf/1047.jpg with size 12.11KB
# Predicting image slf/1052.jpg with size 16.24KB
# Predicting image slf/1055.jpg with size 18.87KB
# Predicting image slf/1070.jpg with size 147.51KB
# Predicting image slf/1073.jpg with size 194.01KB
# Predicting image slf/1074.jpg with size 32.32KB
# Predicting image slf/1076.jpg with size 435.41KB
# Predicting image slf/1085.jpg with size 251.15KB
# Predicting image slf/1087.jpg with size 7.28KB
# Predicting image slf/1092.jpg with size 301.23KB
# Predicting image slf/1094.jpg with size 24.63KB
# Predicting image slf/1111.jpg with size 26.41KB
# Predicting image slf/1113.jpg with size 66.95KB
# Predicting image slf/1118.jpg with size 123.63KB
# Predicting image slf/1127.jpg with size 6.31KB
# Predicting image slf/1134.jpg with size 37.53KB
# Predicting image slf/1135.jpg with size 84.00KB
# Predicting image slf/1137.jpg with size 152.68KB
# Predicting image slf/1147.jpg with size 93.91KB
# Predicting image slf/1149.jpg with size 137.94KB
# Predicting image slf/1151.jpg with size 558.61KB
# Predicting image slf/1154.jpg with size 13.41KB
# Predicting image slf/1156.jpg with size 14.36KB
# Predicting image slf/1157.jpg with size 45.73KB
# Predicting image slf/1162.jpg with size 24.45KB
# Predicting image slf/1164.jpg with size 52.45KB
# Predicting image slf/1165.jpg with size 101.24KB
# Predicting image slf/1167.jpg with size 23.73KB
# Predicting image slf/1174.jpg with size 166.74KB
# Predicting image slf/1177.jpg with size 91.11KB
# Predicting image slf/1180.jpg with size 6.78KB
# Predicting image slf/990.jpg with size 19.23KB
# Predicting image slf/994.jpg with size 60.17KB
# Predicting image slf/995.jpg with size 9.08KB
# {'gbm': {'TP': 95, 'FP': 0, 'FN': 0}, 'neither': {'TP': 138, 'FP': 0, 'FN': 1}, 'slf': {'TP': 40, 'FP': 1, 'FN': 0}}

# %%
# Precision = TP / ( TP + FP) for each class
def calc_precision(TP, FP):
    return TP / (TP + FP)

# Recall = TP / ( TP + FN ) for each class
def calc_recall(TP, FN):
    return TP / (TP+FN)

# F1-score = (2 * precision * recall) / ( precision + recall)
def calc_f1_score(precision, recall):
    return (2*precision*recall) / (precision + recall)



# Create the confusion matrix
#cm = confusion_matrix(true_labels, predicted_labels, labels=["gbm", "slf", "neither"])

# Calculate the metrics
#accuracy = np.trace(cm) / float(np.sum(cm))
#precision = np.diagonal(cm) / np.sum(cm, axis=0)
#recall = np.diagonal(cm) / np.sum(cm, axis=1)
#f1_score = 2 * precision * recall / (precision + recall)

for c in classes.keys():
    precision = calc_precision(classes[c]['TP'],classes[c]['FP'])
    recall = calc_precision(classes[c]['TP'],classes[c]['FN'])
    print(c + ":")
    print("Precision: " + str(precision))
    print("Recall: " + str(recall))
    print("FScore: " + str(calc_f1_score(precision, recall)))
    print()

# Print the metrics
#print("Accuracy: {:.2f}%".format(accuracy * 100))
#print("Precision: {}".format(precision))
#print("Recall: {}".format(recall))
#print("F1 score: {}".format(f1_score))
# Out:
# gbm:
# Precision: 1.0
# Recall: 1.0
# FScore: 1.0
#
# neither:
# Precision: 1.0
# Recall: 0.9928057553956835
# FScore: 0.996389891696751
#
# slf:
# Precision: 0.975609756097561
# Recall: 1.0
# FScore: 0.9876543209876543
